# %% [markdown]
# # Project Description

# %% [markdown]
# My project takes a deeper look into Scientific Computing, expanding on topics covered in Assignment 5 and Coding Lab 7. I was interested in downloading two Spotify Top 200 Chart CSV files, creating dataframes, and analyzing them. I love listening to music so I was excited to use my knowledge in Python and learn something new. The two CSV files were the Top 200 Charts from March 16 2021, and March 16 2020. Using pandas and matplotlib, I was able to make bar and pie charts to better visualize which artists were making up the top songs charts in each year, and also was able to make a random "playlist" generator of ten songs from each year. My project can be seen completely within this notebook, with my functions and test file under modules.

# %% [markdown]
# ## Project Code
#
# If it makes sense for your project, you can have code and outputs here in the notebook as well.

# %%
from my_module.functions import random_playlist_generator, calculate_common, most_songs_on_chart, make_autopct, pie_chart, print_top_ten, both_charts
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import scipy as sp
from scipy import stats
from collections import Counter
from IPython import display

# %% [markdown]
# <code style="background:green;color:black">                                                                                                                     </code>

# %% [markdown]
# <h1><center>SPOTIFY NOW & THEN: COMPARATIVE ANALYSIS FOR 2020 VS. 2021</center></h1>

# %% [markdown]
# <img src="Spotify-Logo.png" width="440" height="340" align="center"/>

# %% [markdown]
# <code style="background:green;color:black">                                                                                                                     </code>

# %% [markdown]
# <h1>March 16, 2021 Spotify Top 200 Analysis</h1>

# %% [markdown]
# <h2>3/16/2021 SPOTIFY TOP 200 SONG CHART</h2>

# %%
df1 = pd.read_csv("data/spotify_charts2021.csv")
pd.set_option("display.max_rows", None, "display.max_columns", None)
df1
# Out:
#      Position                                         Track Name  \
# 0           1                                    drivers license
# 1           2                                          telepatía
# 2           3                                    Save Your Tears
# 3           4                                Leave The Door Open
# 4           5                             Astronaut In The Ocean
# 5           6                                    Blinding Lights
# 6           7                                             DÁKITI
# 7           8                             Heartbreak Anniversary
# 8           9                                            Hold On
# 9          10                                      On The Ground
# 10         11                                        What’s Next
# 11         12                                   Calling My Phone
# 12         13                                            Streets
# ...

# %% [markdown]
# <h2>Top 10 Songs</h2>

# %%
print_top_ten(df1)
# Out:
#    Position              Track Name          Artist  Streams  \
# 0         1         drivers license  Olivia Rodrigo  4454296
# 1         2               telepatía      Kali Uchis  3905552
# 2         3         Save Your Tears      The Weeknd  3743427
# 3         4     Leave The Door Open      Bruno Mars  3600060
# 4         5  Astronaut In The Ocean     Masked Wolf  3599322
# 5         6         Blinding Lights      The Weeknd  3054055
# 6         7                  DÁKITI       Bad Bunny  2974038
# 7         8  Heartbreak Anniversary          Giveon  2682082
# 8         9                 Hold On   Justin Bieber  2650349
# 9        10           On The Ground            ROSÉ  2621556
#
#                                                  URL
# 0  https://open.spotify.com/track/7lPN2DXiMsVn7XU...
# 1  https://open.spotify.com/track/6tDDoYIxWvMLTdK...
# 2  https://open.spotify.com/track/5QO79kh1waicV47...
# 3  https://open.spotify.com/track/7MAibcTli4IisCt...
# ...

# %% [markdown]
# <h2>Most Popular Artists</h2>

# %% [markdown]
# <h3>Who had the most?</h3>

# %%
calculate_common(df1, "Artist")
# Out:
# 'The Weeknd had the most songs on the top 200 list, with 6 songs.'

# %% [markdown]
# <h3>Top 5 Most Occuring Artists</h3>

# %%
most_songs_on_chart(df1,"Artist")
# Out:
# [('The Weeknd', 6),
#  ('Dua Lipa', 5),
#  ('Billie Eilish', 5),
#  ('Juice WRLD', 5),
#  ('Justin Bieber', 4)]

# %% [markdown]
# <h3>Top 10 Most Occuring Artists</h3>

# %%
pie_chart(df1,"Artist")

# %% [markdown]
# <h3>Here is a randomly generated playlist of 10 songs to listen to from the 3/16/2021 top 200 chart!</h3>

# %%
random_playlist_generator(df1)
# Out:
#      Position                        Track Name         Artist  Streams  \
# 167       168  Selfish Love (with Selena Gomez)       DJ Snake   752223
# 41         42                            Anyone  Justin Bieber  1587071
# 25         26                         Good Days            SZA  1888537
# 162       163    Dámelo To’ (feat. Myke Towers)   Selena Gomez   763988
# 83         84              Además de Mí - Remix     Rusherking  1024209
# 115       116                  Relación - Remix           Sech   870358
# 45         46      ROCKSTAR (feat. Roddy Ricch)         DaBaby  1471233
# 149       150               Put Your Records On    Ritt Momney   784304
# 87         88               everything i wanted  Billie Eilish   993592
# 118       119                   Blueberry Faygo      Lil Mosey   863526
#
#                                                    URL
# 167  https://open.spotify.com/track/3XoflnowYPFRPOh...
# 41   https://open.spotify.com/track/31qCy5ZaophVA81...
# ...

# %% [markdown]
# <code style="background:green;color:black">                                                                                                                     </code>

# %% [markdown]
# <h1>March 16, 2020 Spotify Top 200 Analysis</h1>

# %% [markdown]
# <h2>3/16/2020 SPOTIFY TOP 200 SONG CHART</h2>

# %%
df2 = pd.read_csv("data/spotify_charts2020.csv")
df2
# Out:
#      Position                                         Track Name  \
# 0           1                                    Blinding Lights
# 1           2                                            The Box
# 2           3                                       Dance Monkey
# 3           4                                    Don't Start Now
# 4           5                           Intentions (feat. Quavo)
# 5           6                                             Say So
# 6           7                                            Falling
# 7           8                                               Tusa
# 8           9                                            ROXANNE
# 9          10                                            Safaera
# 10         11                                         La Difícil
# 11         12                   death bed (coffee for your head)
# 12         13                        Godzilla (feat. Juice WRLD)
# ...

# %% [markdown]
# <h2>Top 10 Songs</h2>

# %%
print_top_ten(df2)
# Out:
#    Position                Track Name          Artist  Streams  \
# 0         1           Blinding Lights      The Weeknd  5192186
# 1         2                   The Box     Roddy Ricch  5032913
# 2         3              Dance Monkey     Tones And I  4516559
# 3         4           Don't Start Now        Dua Lipa  4092466
# 4         5  Intentions (feat. Quavo)   Justin Bieber  3423605
# 5         6                    Say So        Doja Cat  3360643
# 6         7                   Falling   Trevor Daniel  3216958
# 7         8                      Tusa         KAROL G  3125321
# 8         9                   ROXANNE  Arizona Zervas  3039078
# 9        10                   Safaera       Bad Bunny  2998577
#
#                                                  URL
# 0  https://open.spotify.com/track/0sf12qNH5qcw8qp...
# 1  https://open.spotify.com/track/0nbXyq5TXYPCO7p...
# 2  https://open.spotify.com/track/1rgnBhdG2JDFTbY...
# 3  https://open.spotify.com/track/6WrI0LAC5M1Rw2M...
# ...

# %% [markdown]
# <h2>Most Popular Artists</h2>

# %% [markdown]
# <h3>Who had the most?</h3>

# %%
calculate_common(df2, "Artist")
# Out:
# 'Bad Bunny had the most songs on the top 200 list, with 18 songs.'

# %% [markdown]
# <h3>Top 5 Most Occuring Artists</h3>

# %%
most_songs_on_chart(df2,"Artist")
# Out:
# [('Bad Bunny', 18),
#  ('Lil Uzi Vert', 14),
#  ('Post Malone', 7),
#  ('Billie Eilish', 7),
#  ('Harry Styles', 4)]

# %% [markdown]
# <h3>Top 10 Most Occuring Artists</h3>

# %%
pie_chart(df2,"Artist")

# %% [markdown]
# <h3>Here is a randomly generated playlist of 10 songs to listen to from the 3/16/2020 top 200 chart!</h3>

# %%
random_playlist_generator(df2)
# Out:
#      Position                                Track Name        Artist  \
# 19         20                                Ignorantes     Bad Bunny
# 76         77                                   No Idea   Don Toliver
# 92         93                                  It's You     Ali Gatie
# 43         44                               After Hours    The Weeknd
# 133       134                      No Me Conoce - Remix   Jhay Cortez
# 159       160                                 Heartless    The Weeknd
# 52         53                                Baby Pluto  Lil Uzi Vert
# 151       152                                      Dior     Pop Smoke
# 166       167  Money In The Grave (Drake ft. Rick Ross)         Drake
# 22         23                                 Adore You  Harry Styles
#
#      Streams                                                URL
# 19   2489763  https://open.spotify.com/track/38RIEav39FGi86j...
# 76   1072219  https://open.spotify.com/track/7AzlLxHn24DxjgQ...
# ...

# %% [markdown]
# <code style="background:green;color:black">                                                                                                                     </code>

# %% [markdown]
# <h1>Which artists were popular in both years?</h2>

# %%
both_charts(df1, df2, "Artist")
# Out:
#   Artists in Top 50 on Both Charts
# 0                         Doja Cat
# 1                      Myke Towers
# 2                         Dua Lipa
# 3                    Justin Bieber
# 4                        Bad Bunny
# 5                     Harry Styles
# 6                       The Weeknd
# 7                    Lewis Capaldi
# 8                          KAROL G

# %% [markdown]
# <code style="background:green;color:black">                                                                                                                     </code>

# %% [markdown]
# <code style="background:green;color:black">                                                                                                                     </code>

# %% [markdown]
# <code style="background:green;color:black">                                                                                                                     </code>

# %% [markdown]
# #### Extra Credit (*optional*)

# %% [markdown]
# 1. I have taken introductory programming classing in Java and C++, but this was my first class in Python.
# 2. While I do not think my project was extremely advanced, I beleive I went above what was taught in the course by diving further into Pandas and data visualization with the bar graphs and pie charts. I also was able to learn more about how to customize Markdown cells, including adding images and color. I learned how to upload CSV files, as well as compare two Dataframes to one another to find their common elements, which was really interesting!  This project made me really excited to continue my journey in Python and even keep working on this project to make it more and more advanced as I grow my skill set. I was glad to take the opportunity to do a project rather than a final so I could use Python to analyze something I was interested in, which I think is important for doing meaningful work.
